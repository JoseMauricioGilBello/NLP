# %% [markdown]
# <img src='https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcQ-VfNtOyJbsaxu43Kztf_cv1mgBG6ZIQZEVw&usqp=CAU'>
#
# # Procesamiento de Lenguage Natural
#
# ## Taller #8: Agrupación de textos
# `Fecha de entrega: Abril 29, 2021. (Antes del inicio de la próxima clase).`
#
# `Modo de entrega: Subir link de GitHub al aula virtual.`

# %%
import re
import json
import pandas as pd

from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer

from sklearn.neighbors import NearestNeighbors
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA

import matplotlib.pyplot as plt
import plotly.graph_objs as go
from plotly.offline import iplot

# %%
# Cargar datos
path = '../../archivos/reviews_vidjew_es.csv'
data = pd.read_csv(path)
data.head()
# Out:
#     review_id          product_id          reviewer_id  stars  \
# 0  es_0825565  product_es_0370490  reviewer_es_0174781      3
# 1  es_0227934  product_es_0354224  reviewer_es_0411613      3
# 2  es_0468601  product_es_0665460  reviewer_es_0348315      1
# 3  es_0814494  product_es_0692692  reviewer_es_0951508      5
# 4  es_0206329  product_es_0728826  reviewer_es_0493255      4
#
#                                          review_body            review_title  \
# 0         Buen. Buena calidad, y buena presentación.                Contenta
# 1  Un producto a perfecto, para salir de casa con...            Versatilidad
# 2  No funciona con Nintendo Switch. No hay forma ...      Decepción absoluta
# 3  Recomendado, los utilizo para pc y no me dan n...  Auriculares Pecham ps4
# 4  El cable funciona bien podria ser un poco mas ...                Perfecto
#
#   language product_category
# 0       es          jewelry
# 1       es      video_games
# 2       es      video_games
# 3       es      video_games
# 4       es      video_games

# %%
# Cargar datos
path = 'D:/Especializacion/NLP/Taller8/reviews_vidjew_es.csv'
data = pd.read_csv(path)
data.head()
# Out:
#     review_id          product_id          reviewer_id  stars  \
# 0  es_0825565  product_es_0370490  reviewer_es_0174781      3
# 1  es_0227934  product_es_0354224  reviewer_es_0411613      3
# 2  es_0468601  product_es_0665460  reviewer_es_0348315      1
# 3  es_0814494  product_es_0692692  reviewer_es_0951508      5
# 4  es_0206329  product_es_0728826  reviewer_es_0493255      4
#
#                                          review_body            review_title  \
# 0         Buen. Buena calidad, y buena presentación.                Contenta
# 1  Un producto a perfecto, para salir de casa con...            Versatilidad
# 2  No funciona con Nintendo Switch. No hay forma ...      Decepción absoluta
# 3  Recomendado, los utilizo para pc y no me dan n...  Auriculares Pecham ps4
# 4  El cable funciona bien podria ser un poco mas ...                Perfecto
#
#   language product_category
# 0       es          jewelry
# 1       es      video_games
# 2       es      video_games
# 3       es      video_games
# 4       es      video_games

# %% [markdown]
# ###  `[10 pts]` Punto 1: Hacer pre-procesamiento del texto

# %%
import re
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer
stopwords_sp = stopwords.words('spanish')


def pre_procesado(texto):
    texto = texto.lower()
    texto = re.sub(r"[\W\d_]+", " ", texto)
    texto = texto.split() # Tokenizar
    texto = [palabra for palabra in texto if palabra not in stopwords_sp]
    texto = " ".join(texto)
    return texto

tfidf_vect = TfidfVectorizer(preprocessor=pre_procesado)
tfidf = tfidf_vect.fit_transform(data.review_body.values)
tfidf_matrix = pd.DataFrame(tfidf.toarray(), columns = tfidf_vect.get_feature_names())

# %% [markdown]
# ###  `[10 pts]` Punto 2: Método del codo para determinar $K$

# %%
ks = []
k_inertias = []

for k in range(1,10):
    kmeans = KMeans(n_clusters=k).fit(tfidf_matrix)
    k_inertia = kmeans.inertia_
    
    ks.append(k)
    k_inertias.append(k_inertia)
    
    
# list(zip(ks,k_inertias))

plt.xlabel("Número de cúmulos")
plt.ylabel("Inercia")
plt.title("Método del codo")
plt.plot(ks, k_inertias, 'bx-');

# %% [markdown]
# ###  `[10 pts]` Punto 3: Entrenar modelo con el $K$ escogido

# %%
k = 4
model = KMeans(n_clusters = k)
model.fit(tfidf_matrix)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=4, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %% [markdown]
# ###  `[15 pts]` Punto 4: Interpretación de los clusters

# %%
data["cluster"] = model.labels_
data
# Out:
#       review_id          product_id          reviewer_id  stars  \
# 0    es_0825565  product_es_0370490  reviewer_es_0174781      3
# 1    es_0227934  product_es_0354224  reviewer_es_0411613      3
# 2    es_0468601  product_es_0665460  reviewer_es_0348315      1
# 3    es_0814494  product_es_0692692  reviewer_es_0951508      5
# 4    es_0206329  product_es_0728826  reviewer_es_0493255      4
# ..          ...                 ...                  ...    ...
# 995  es_0427672  product_es_0899883  reviewer_es_0474735      2
# 996  es_0059540  product_es_0702564  reviewer_es_0754753      3
# 997  es_0303349  product_es_0678671  reviewer_es_0172313      5
# 998  es_0659961  product_es_0294943  reviewer_es_0554554      4
# 999  es_0441429  product_es_0478207  reviewer_es_0691110      2
#
#                                            review_body  \
# 0           Buen. Buena calidad, y buena presentación.
# 1    Un producto a perfecto, para salir de casa con...
# 2    No funciona con Nintendo Switch. No hay forma ...
# 3    Recomendado, los utilizo para pc y no me dan n...
# 4    El cable funciona bien podria ser un poco mas ...
# ..                                                 ...
# 995  En la foto parece que la cadena sea más gruesa...
# 996      Bien por su precio, la cadena demasiado fina.
# 997  Muy bien!! Ahora tengo organizados los pendien...
# 998  Las tapas para los joystics no están nada mal,...
# 999  Mi primer impulso fue ponerlo a la venta nada ...
#
#                                      review_title language product_category  \
# 0                                        Contenta       es          jewelry
# 1                                    Versatilidad       es      video_games
# 2                              Decepción absoluta       es      video_games
# 3                          Auriculares Pecham ps4       es      video_games
# 4                                        Perfecto       es      video_games
# ..                                            ...      ...              ...
# 995                               Cadena muy fina       es          jewelry
# 996                                             E       es          jewelry
# 997                                        Bonito       es          jewelry
# 998  No está mal pero sólo he probado las fundas.       es      video_games
# 999                                  Decepcionado       es      video_games
#
#      cluster
# 0          1
# 1          2
# 2          0
# 3          3
# 4          3
# ..       ...
# 995        3
# 996        3
# 997        3
# 998        0
# 999        0
#
# [1000 rows x 9 columns]

# %%
# Out:
# CLUSTERS:
#
# Cluster 0:
# COUNT  52 comments (5.20% of the data)
# TERMS  perfecto llegó tiempo gracias sido rápido justo juego tamaño producto recomendable rapido poner funciona igual funcionar buen mano castellano encanta
# REPRESENTATIVE COMMENTS
# * Todo en perfecto estado
# * Perfecto y en tiempo
# * Llegó a tiempo y en perfecto estado
#
#
# Cluster 1:
# COUNT  211 comments (21.10% of the data)
# TERMS  bien juego bastante aunque cadena funciona si viene español caja dos jugar solo producto mas regalo precio ps así imagen
# REPRESENTATIVE COMMENTS
# * Está bien por su precio
# * Por el precio que tiene está muy bien
# * Esta bien,fue un regalo
#
#
# Cluster 2:
# COUNT  551 comments (55.10% of the data)
# TERMS  producto llegado si buen regalo día mas bonitos foto mando bonita llego pulsera solo plata llegó pequeños tiempo mal amazon
# REPRESENTATIVE COMMENTS
# * El producto ha llegado antes de lo previsto, me ha gustado su calidad es más pequeño de lo esperado pero me gusta. Vale la pena.
# * No ha llegado el collar . Las demás cosas que he comprado en Amazon han llegado, pero este producto no me ha llegado.
# * Fue para un regalo, le ha encantado y llegó de un día para otro.
#
#
# Cluster 3:
# COUNT  123 comments (12.30% of the data)
# TERMS  calidad precio buena bien mala pedir puede buen cumple bueno relación regalo cierre demasiado parece esperaba aunque compra baja cadena
# REPRESENTATIVE COMMENTS
# * Calidad precio muy buena
# * Calidad precio buena
# * Calidad precio buena
#
#
# Cluster 4:
# COUNT  63 comments (6.30% of the data)
# TERMS  bonito pequeño bien queda colgante plata tamaño collar regalo foto adecuado calidad diseño parece tal cadena gustado fotos grande tiempo
# REPRESENTATIVE COMMENTS
# * Bonito fue para un regalo y bien
# * Algo pequeño, pero bonito
# * Bonito y adecuado para lo que es

# %%
nbrs = NearestNeighbors(n_neighbors=3, metric='euclidean').fit(tfidf_matrix.values)

clust_cnt = data['cluster'].value_counts()
clust_cnt_pct = data['cluster'].value_counts(normalize=True)

centroides = model.cluster_centers_

# %%
terms = tfidf_vect.get_feature_names()
order_centroids = centroids.argsort()[:, ::-1]

for i in range(k):
    print(f"Cluster # {i}")
    print(f"Tiene {clust_cnt[i]} registros ({clust_cnt_pct[i]:.2%} de los datos)")
    print()
    
    print("TÉRMINOS MÁS REPRESENTATIVOS")
    for ind in order_centroids[i][:20]:
        print(terms[ind], end=" ")
    print()
    print()
    
    print(f"DOCUMENTOS MÁS REPRESENTATIVOS")
    for vecino in data.iloc[nbrs.kneighbors([centroides[i]])[1][0]].review_body.values:
        print(f" *** {vecino}")
        print()
        
    print()
    print("********************************************")
    print()
# Out:
# Cluster # 0
# Tiene 581 registros (58.10% de los datos)
#
# TÉRMINOS MÁS REPRESENTATIVOS
# juego perfecto si mas bonitos regalo foto esperaba tiempo jugar mando mejor aunque hijo llegó caja solo funciona gustado pequeños
#
# DOCUMENTOS MÁS REPRESENTATIVOS
#  *** Esperaba más del juego.
#
#  *** Un juego para mi hijo. No se ha pasado mucho tiempo jugando con él. No puedo opinar mucho más sobre este juego.
#
#  *** Llegó a tiempo y en perfecto estado
#
#
# ********************************************
#
# Cluster # 1
# Tiene 143 registros (14.30% de los datos)
#
# TÉRMINOS MÁS REPRESENTATIVOS
# calidad buena precio mala buen puede bastante pedir compra bien regalo relación bueno cierre cumple gustado demasiado bonitos perfectamente producto
#
# DOCUMENTOS MÁS REPRESENTATIVOS
#  *** Calidad precio buena
#
#  *** Calidad precio buena
#
#  *** Calidad precio muy buena
#
#
# ********************************************
#
# Cluster # 2
# Tiene 128 registros (12.80% de los datos)
#
# TÉRMINOS MÁS REPRESENTATIVOS
# producto llegado día buen todavía llegó entregado bien sido llego solo llega nunca perfecto previsto regalo gracias hoy si amazon
#
# DOCUMENTOS MÁS REPRESENTATIVOS
#  *** Hoy es el día límite y no me he llegado el producto.
#
#  *** No ha llegado el collar . Las demás cosas que he comprado en Amazon han llegado, pero este producto no me ha llegado.
#
#  *** El producto en buen estado. Perfecto.
#
#
# ********************************************
#
# Cluster # 3
# Tiene 148 registros (14.80% de los datos)
#
# TÉRMINOS MÁS REPRESENTATIVOS
# bien bonito cadena queda precio colgante pequeño parece foto regalo tamaño quedan plata collar mas tiempo calidad juego aunque grande
#
# DOCUMENTOS MÁS REPRESENTATIVOS
#  *** Bonito fue para un regalo y bien
#
#  *** Por el precio que tiene está muy bien
#
#  *** Está bien por su precio
#
#
# ********************************************

# %% [markdown]
# ###  `[BONUS: 3 pts]` Visualización usando PCA

# %%
pca = PCA(n_components=2)

result = pca.fit_transform(tfidf_matrix)
result = pd.DataFrame(result)
result.columns = ['X', 'Y']
result['cluster'] = data.nombres_clusters.values
result['review_body'] = data.review_body.apply(lambda val: val[:140])
result['colores'] = result['cluster'].map(colorsIdx)


result.head()


trace = go.Scatter(x=result['X'].values,
                   y=result['Y'].values,
                   text=result['review_body'].values,
                   mode='markers',
                   marker=dict(color=result['colores'].values)) 

layout = go.Layout(title="PCA")

fig = go.Figure(data=trace, layout=layout)
iplot(fig)
# Out:
# <div>                            <div id="1559eba6-a6b2-4ea9-8904-4801432c1e1c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1559eba6-a6b2-4ea9-8904-4801432c1e1c")) {                    Plotly.newPlot(                        "1559eba6-a6b2-4ea9-8904-4801432c1e1c",                        [{"marker": {"color": [null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, nul ...

# %% [markdown]
# # Comparación

# %% [markdown]
# ### `[BONUS 20 pts (validos para cualquier tarea)]`
# ### Hacer predicción para estas dos frases de los dos modelos (clasificación y $k$-means)

# %%
test = ["Necesitas el juego inicial para eso", "Preciosos estos aretes, buena calidad"]
nuevo_trans = tfidf_vect.transform(test)
[clusters[i] for i in model.predict(nuevo_trans)]
# Out:
# ['1', '2']
